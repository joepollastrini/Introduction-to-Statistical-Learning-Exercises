# %% [markdown]
# 8)
# This exercise relates to the College data set, which can be found in the file College.csv.  It contains a number of variables for 777 different universities and colleges in the US.  The variables are:
#
# * Private : Public/private indicator
# * Apps : Number of applications received
# * Accept : Number of applicants accepted
# * Enroll : Number of new students enrolled
# * Top10perc : New students from top 10 % of high school class
# * Top25perc : New students from top 25 % of high school class
# * F.Undergrad : Number of full-time undergraduates
# * P.Undergrad : Number of part-time undergraduates
# * Outstate : Out-of-state tuition
# * Room.Board : Room and board costs
# * Books : Estimated book costs
# * Personal : Estimated personal spending
# * PhD : Percent of faculty with Ph.D.’s
# * Terminal : Percent of faculty with terminal degree
# * S.F.Ratio : Student/faculty ratio
# * perc.alumni : Percent of alumni who donate
# * Expend : Instructional expenditure per student
# * Grad.Rate : Graduation rate

# %% [markdown]
# a) Read in the data
#
# b) View the data

# %%
import os
import pandas as pd
college = pd.read_csv(os.path.join(os.getcwd(), 'College.csv'))
#college

# %%
#rename the first column
college.rename(columns={'Unnamed: 0':'School'}, inplace=True)
college
# Out:
#                              School Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %% [markdown]
# c)
# i. Summarize the data

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ii. Scatterplot the first 10 variables

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.plotting.scatter_matrix(college.iloc[:,1:11], figsize=(15,10));

# %% [markdown]
# iii. Side by side boxplots of Outstate vs Private

# %%
sns.boxplot(x = college['Private'], y=college['Outstate']);

# %% [markdown]
# iv. Create variable Elite (indicator if Top10perc > 50).  See how many elite universities there are.  Create a boxplot of Outstate vs. Elite

# %%
college['Elite'] = college['Top10perc'].apply(lambda x: 1 if x > 50 else 0)
print(college['Elite'].value_counts())
sns.boxplot(x = college['Elite'], y = college['Outstate']);
# Out:
# 0    699
# 1     78
# Name: Elite, dtype: int64

# %% [markdown]
# v.  Create histograms with differing number of bins

# %%
from scipy import stats
fig = plt.figure(figsize=(10, 6), dpi= 80, facecolor='w', edgecolor='k')
ax1 = fig.add_subplot(2, 2, 1)
sns.distplot(college['PhD'], bins=10, kde=False, fit=stats.norm);

ax2 = fig.add_subplot(2,2,2)
sns.distplot(college['PhD'], bins=25, kde=False, fit=stats.norm);

ax3 = fig.add_subplot(2,2,3)
sns.distplot(college['F.Undergrad'], bins=25, kde=False, fit=stats.norm);

ax4 = fig.add_subplot(2,2,4)
sns.distplot(college['F.Undergrad'], bins=50, kde=False, fit=stats.norm);

# %% [markdown]
# ***

# %% [markdown]
# 9) This exercise involves the Auto data set studied in the lab.  Make sure that the missing values have been removed from the data.

# %%
auto = pd.read_csv(os.path.join(os.getcwd(), 'Auto.csv'))
auto.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# a) Which of the data is qualitative, quantitative?
#
# ****Answer:****
#
# Qualitative:  name, possibly origin?
#
# Quantitativ:  mpg, cylinders, displacement, weight, acceleration, year

# %% [markdown]
# b) What is the range for the quantitative predictors?

# %%
desc = auto.describe().transpose()
desc[['min', 'max']]
# Out:
#                  min     max
# mpg              9.0    46.6
# cylinders        3.0     8.0
# displacement    68.0   455.0
# weight        1613.0  5140.0
# acceleration     8.0    24.8
# year            70.0    82.0
# origin           1.0     3.0

# %% [markdown]
# c) What is the mean and standard deviation for each quantitative predictor?

# %%
desc[['mean', 'std']]
# Out:
#                      mean         std
# mpg             23.515869    7.825804
# cylinders        5.458438    1.701577
# displacement   193.532746  104.379583
# weight        2970.261965  847.904119
# acceleration    15.555668    2.749995
# year            75.994962    3.690005
# origin           1.574307    0.802549

# %% [markdown]
# d) Remove the 10th through 85th observations and repeat b and c

# %%
removedBot = auto.iloc[:9,:]
removedTop = auto.iloc[85:,:]
removed = pd.concat((removedBot, removedTop), axis=0).reset_index()

# %%
desc = removed.describe().transpose()
desc[['min', 'max', 'mean', 'std']]
# Out:
#                  min     max         mean         std
# index            0.0   396.0   233.869159   97.150889
# mpg             11.0    46.6    24.438629    7.908184
# cylinders        3.0     8.0     5.370717    1.653486
# displacement    68.0   455.0   187.049844   99.635385
# weight        1649.0  4997.0  2933.962617  810.642938
# acceleration     8.5    24.8    15.723053    2.680514
# year            70.0    82.0    77.152648    3.111230
# origin           1.0     3.0     1.598131    0.816163

# %% [markdown]
# f) Do any variables suggest predictability for mpg?

# %%
pd.plotting.scatter_matrix(auto, figsize=(15,10));

# %%
fig = plt.figure(figsize=(12, 8), dpi= 80, facecolor='w', edgecolor='k')

ax1 = fig.add_subplot(2, 2, 1)
sns.regplot(x=auto['displacement'], y=auto['mpg']);

ax2 = fig.add_subplot(2, 2, 2)
sns.regplot(x=auto['weight'], y=auto['mpg']);

ax3 = fig.add_subplot(2, 2, 3)
sns.regplot(x=auto['acceleration'], y=auto['mpg']);

ax4 = fig.add_subplot(2, 2, 4)
sns.regplot(x=auto['year'], y=auto['mpg']);

# %%
fig = plt.figure(figsize=(10, 4), dpi= 80, facecolor='w', edgecolor='k')

ax1 = fig.add_subplot(1, 2, 1)
sns.boxplot(x = auto['origin'], y = auto['mpg']);

auto['make'] = auto['name'].apply(lambda x: x.split(' ')[0].strip())
ax2 = fig.add_subplot(1, 2, 2)
sns.boxplot(x = auto['make'], y = auto['mpg']);

# %% [markdown]
# ****Answer:**** Variables displacement, weight, year, acceleration, and origin all seem to me useful in predicting mpg.  Some variables might be highly correlated, such as weight and displacement.  There may be usefulness in the make of the car as well.  A further dive into it is necessary.

# %% [markdown]
# ***

# %% [markdown]
# 10) This exercise involves the Boston housing data set.

# %% [markdown]
# a) Load data.  How many rows and columns are there and what does each represent?

# %%
boston = pd.read_csv(os.path.join(os.getcwd(), 'Boston.csv')
                     , delimiter=r"\s+"
                     , names=['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax'
                              , 'ptratio', 'b', 'lstat', 'medv'])
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# crim       506 non-null float64
# zn         506 non-null float64
# indus      506 non-null float64
# chas       506 non-null int64
# nox        506 non-null float64
# rm         506 non-null float64
# age        506 non-null float64
# dis        506 non-null float64
# rad        506 non-null int64
# tax        506 non-null float64
# ptratio    506 non-null float64
# b          506 non-null float64
# lstat      506 non-null float64
# medv       506 non-null float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %% [markdown]
# ****Answer:****  There are 506 observations and 14 parameters.  The following was found online for each variable meaning:
# * crim - per capita crime rate by town
# * zn - proportion of residential land zoned for lots over 25000 sq. ft.
# * indus - proportion of non-retail business acres per town
# * chas - Charles River dummy variable (1 if tract bounds river)
# * nox - nitric oxides concentration (parts per 10 million)
# * rm - average number of rooms per dwelling
# * age - proportion of owner-occupied units built prior to 1940
# * dis - weighted distances to five Boston employment centres
# * rad - index of accessibility to radial highways
# * tax - full value property tax rate per USD 10000
# * ptratio - pupil to teacher ratio
# * b - 1000(B - 0.63)^2 where B is the proportion of blacks by town
# * lstat - percentage of lower status of the population
# * medv - median value of owner occupied homes in USD 1000

# %% [markdown]
# c) Are there any predictors associated with per capita crime rate?

# %%
pd.plotting.scatter_matrix(boston, figsize=(15,10));

# %%
fig = plt.figure(figsize=(12, 15), dpi= 80, facecolor='w', edgecolor='k')
for i, c in enumerate(boston.columns[1:]):
    fig.add_subplot(len(boston.columns[1:])/3 + 1, 3, i+1)
    sns.regplot(x=boston[c], y=boston['crim']);

# %%
len(boston['rad'].unique())
# Out:
# 9

# %% [markdown]
# ****Answer:****
# * ****zn**** seems to be indicative of crime rate.  Specifically zn != 0 implies no crime rates.
# * a specific ****indus**** value implies crime rates > 0
# * ****chas**** - being along the charles river implies a low crime rate
# * a high ****rad**** value implies crime rates > 0
# * ****age**** - a larger proportion of older homes implies a larger crime rate
# * ****medv**** - higher median home value implies lower crime rates
#
# * ****rad**** only has 9 unique values, so could probably be treated as a qualitative variable with grouping

# %% [markdown]
# d) Do any of the suburbs of Boston have particularly high crime rates, tax rates, etc.?

# %%
fig = plt.figure(figsize=(12, 15), dpi= 80, facecolor='w', edgecolor='k')
for i, c in enumerate(boston.columns):
    fig.add_subplot(len(boston.columns[1:])/3 + 1, 3, i+1)
    sns.distplot(boston[c], kde=False, fit=stats.norm);

# %%
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# ****Answer:****
# * crim - skewed, outliers on high side, most little to no crime
# * zn - skewed, outliers on high side, most 0 proportion zoned above 25k sq ft
# * inuds - two groups?
# * chas - indicator, most 0
# * nox - skewed, outliers above
# * age - skewed, outliers on low side, most areas very old (close to 100% older than 1940)
# * dis - skewed, outliers high, most close to employment centers
# * rad - two groups
# * tax - outliers high
# * ptratio - spread out, large amount in 20 range
# * b - skewed, outliers to downside, at 400 => 120% blacks per town?  Something doesn't add up
# * lstat - skewed, outliers high
# * medv - skewed, large group of outliers high

# %% [markdown]
# e) How many suburbs bound the charles river?

# %%
boston['chas'].value_counts()
# Out:
# 0    471
# 1     35
# Name: chas, dtype: int64

# %% [markdown]
# f) What is the median pupil-teacher ratio?

# %%
boston['ptratio'].describe().transpose()['50%']
# Out:
# 19.05

# %% [markdown]
# h) How many suburbs average more than 8 rooms per dwelling? Comment on these suburbs.

# %%
eightRooms = boston.loc[boston['rm'] > 8]
eightRooms.describe()
# Out:
#             crim         zn      indus       chas        nox         rm  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    0.718795  13.615385   7.078462   0.153846   0.539238   8.348538
# std     0.901640  26.298094   5.392767   0.375534   0.092352   0.251261
# min     0.020090   0.000000   2.680000   0.000000   0.416100   8.034000
# 25%     0.331470   0.000000   3.970000   0.000000   0.504000   8.247000
# 50%     0.520140   0.000000   6.200000   0.000000   0.507000   8.297000
# 75%     0.578340  20.000000   6.200000   0.000000   0.605000   8.398000
# max     3.474280  95.000000  19.580000   1.000000   0.718000   8.780000
#
#              age        dis        rad         tax    ptratio           b  \
# count  13.000000  13.000000  13.000000   13.000000  13.000000   13.000000
# mean   71.538462   3.430192   7.461538  325.076923  16.361538  385.210769
# std    24.608723   1.883955   5.332532  110.971063   2.410580   10.529359
# ...

# %% [markdown]
# Crime rates very low, max 3.5%, below median for pupil teachr ratio, median home price high, lstat low
